# %%
# !pip install streamlit pandas folium plotly streamlit-folium
# Out:
# ...
#      |████████████████████████████████| 9.1 MB 1.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 102 kB 1.1 MB/s ta 0:00:01
# ...
#      |████████████████████████████████| 15.6 MB 613 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 165 kB 221 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.2 MB 507 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 170 kB 611 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 80 kB 455 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 295 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 25.6 MB 445 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 727 kB 56 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 237 kB 211 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 96 kB 213 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 55 kB 198 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 96 kB/s  eta 0:00:01
# ...

# %%
# !streamlit run weighbridge_dashboard_v1.py
# Out:
#   👋 Welcome to Streamlit!
#
#   If you're one of our development partners or you're interested in getting
#   personal technical support or Streamlit updates, please enter your email
#   address below. Otherwise, you may leave the field blank.
#
#   Email:  ^C
# 2025-05-29 08:06:20.921
